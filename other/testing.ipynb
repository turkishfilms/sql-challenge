# %%
import pandas as pd
from sqlalchemy import create_engine, text
from sqlalchemy import Column, Integer, String, Float
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import Session
Base = declarative_base()

# %%
path = r"data/Census_Data.sqlite"
path2 = r"data/zip_census.sqlite"

# %%
sql_query = "SELECT * FROM Census_Data"
sql2 = "SELECT * FROM zip_census"

# %%
engine = create_engine(f"sqlite:///{path}")
conn = engine.connect()
Base.metadata.create_all(engine)
session = Session(bind=engine)

# %%
def run_sql_query(sql_query, engine):
    with engine.connect() as connection:
        data = connection.execute(text(sql_query))
        # connection.commit()
    return data

def showsql(sql):
    for entry in sql:
        print(entry)

# %%
data = pd.read_sql(sql = sql_query, con = conn,)
data.head()
# Out:
#          CityState         city state  Population  White Population  \
# 0      HOUSTON, TX      HOUSTON    TX     3061887           1775897
# 1      CHICAGO, IL      CHICAGO    IL     2702091           1318869
# 2     BROOKLYN, NY     BROOKLYN    NY     2595259           1126111
# 3  LOS ANGELES, CA  LOS ANGELES    CA     2426413           1068202
# 4        MIAMI, FL        MIAMI    FL     1820704           1361009
#
#    Black Population  Native American Population  Asian Population  \
# 0            684416                       11586            230549
# 1            843633                        7554            161478
# 2            870465                        8744            297890
# 3            324842                       15949            273829
# 4            363514                        2250             33144
#
#    Hispanic Population  Education None  ...  \
# 0              1368287           54180  ...
# 1               785374           32800  ...
# ...

# %%
class NahNi(Base):
    __tablename__ = "Census_Data"
    # data_ID = Column(Integer, )
    CityState = Column(Integer)
    city = Column(Integer)
    state = Column(Integer)
    Population = Column(Integer,primary_key = True)
    White_Population = Column(Integer)
    Black_Population = Column(Integer)
    Native_American_Population = Column(Integer)
    Asian_Population = Column(Integer)
    Hispanic_Population = Column(Integer)
    Education_None = Column(Integer)
    Education_High_School = Column(Integer)
    Education_GED = Column(Integer)
    Education_Associates = Column(Integer)
    Education_Bachelors = Column(Integer)
    Education_Masters = Column(Integer)
    Education_Professional = Column(Integer)
    Education_Doctorate = Column(Integer)
    Poverty = Column(Integer)
    Employment_Labor_Force = Column(Integer)
    Employment_Unemployed = Column(Integer)
    Employment_Male_Computer_Engineering = Column(Integer)
    Employment_Female_Computer_Engineering = Column(Integer)
    Median_Age = Column(Integer)
    Median_Male_Age = Column(Integer)
    Median_Female_Age = Column(Integer)
    Household_Income_= Column(Integer)
    Income_Per_Capita = Column(Integer)
    Median_Gross_Rent = Column(Integer)
    Median_Home_Value = Column(Integer)
    lat = Column(Integer)
    lng = Column(Integer)
# Out:
#   File "C:\Users\ddram\AppData\Local\Temp\ipykernel_10848\2493994932.py", line 8
#     White Population = Column(Integer)
#                    ^
# SyntaxError: invalid syntax

# %%
# dude = session.query(NahNii)
# for dudes in dude:
#     print(dudes)

# %%
# Find those players from the USA who were born after 1989
born_after_1989 = session.query(NahNi).\
    filter(NahNi.Median_Male_Age > 20).filter(NahNi.Median_Female_Age == 21).\
    count()
print(f"{born_after_1989} USA players were born after 1989")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# g:\programs\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1900                     self.dialect.do_execute(
# -> 1901                         cursor, statement, parameters, context
#    1902                     )
#
# g:\programs\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     735     def do_execute(self, cursor, statement, parameters, context=None):
# --> 736         cursor.execute(statement, parameters)
#     737
#
# OperationalError: no such column: Census_Data.White_Population
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
Base.metadata.create_all(engine)
